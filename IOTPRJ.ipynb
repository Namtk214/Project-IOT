# %% [markdown]
# <a href="https://colab.research.google.com/github/Namtk214/Project-IOT/blob/main/IOTPRJ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Preparing

# %%
# !mkdir data/
# Out:
# mkdir: cannot create directory ‘data/’: File exists

# %%
# !gdown  1gzWOtABiVmJ38usCSDe5F9gR2tECt3zu -O data/
# !gdown  15lwipssmC_K82ukRfb0uVCiDH1TZ3QCf -O data/
# !gdown  1nIo1_wBmkovz-u_BCsV5c1Kbz6ZqoKwq -O data/
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gzWOtABiVmJ38usCSDe5F9gR2tECt3zu
# To: /content/data/landmark_val.csv
# 100% 369k/369k [00:00<00:00, 106MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=15lwipssmC_K82ukRfb0uVCiDH1TZ3QCf
# To: /content/data/landmark_train.csv
# 100% 1.28M/1.28M [00:00<00:00, 123MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1nIo1_wBmkovz-u_BCsV5c1Kbz6ZqoKwq
# To: /content/data/landmark_test.csv
# 100% 320k/320k [00:00<00:00, 104MB/s]

# %%
# !pip install mediapipe==0.10.18
# Out:
# Requirement already satisfied: mediapipe==0.10.18 in /usr/local/lib/python3.10/dist-packages (0.10.18)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (3.8.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (4.25.5)
# Requirement already satisfied: sounddevice>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.5.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe==0.10.18) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.18) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.18) (1.17.0)

# %%
# !pip install torchmetrics
# Out:
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/dist-packages (1.6.1)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.5.1+cu121)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (0.11.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)

# %% [markdown]
# Preprocessing

# %%
import os
import cv2
import mediapipe as mp
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch import optim
import yaml
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

# %% [markdown]
# Define neural network

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path,"r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
# class NeuralNetwork(nn.Module):
#   def __init__(self):
#     super(NeuralNetwork, self).__init__()
#     self.flatten = nn.Flatten()
#     list_label = label_dict_from_config_file("/content/hand_gesture.yaml")
#     self.linear_relu_stack = nn.Sequential(
#         nn.Linear(63, 128),
#         nn.ReLU(),
#         nn.BatchNorm1d(128),
#         nn.Linear(128, 128),
#         nn.ReLU(),
#         nn.Dropout(p=0.4),
#         nn.Linear(128, 128),
#         nn.ReLU(),
#         nn.Dropout(p=0.4),
#         nn.Linear(128, 128),
#         nn.ReLU(),
#         nn.Dropout(p=0.6),
#         nn.Linear(128, len(list_label)),
#     )

#   def forward(self, x):
#     x = self.flatten(x)
#     logits = self.linear_relu_stack(x)
#     return logits

#   def predict(self, x, threshold=0.8):
#     logits = self(x)
#     softmax_prob = nn.softmax(dim=1)(logits)
#     chosen_ind = torch.argmax(softmax_prob, dim=1)
#     return torch.where(softmax_prob[0, chosen_ind] > threshold, chosen_ind, -1)

#   def predict_with_known_class(self, x):
#     logits = self(x)
#     softmax_prob = nn.softmax(dim=1)(logits)
#     return torch.argmax(softmax_prob, dim=1)

#   def score(self, logits):
#     softmax_prob = nn.softmax(dim=1)(logits)
#     return -torch.max(softmax_prob, dim=1)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("hand_gesture.yaml")
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(63, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.6),
            nn.Linear(128, len(list_label)),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob,dim=1)
        return torch.where(softmax_prob[0,chosen_ind]>threshold,chosen_ind,-1)

    def predict_with_known_class(self,x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob,dim=1)

    def score(self,logits):
        return -torch.amax(logits,dim=1)

# %%
class HandLandmarksDetector():
  def __init__(self) -> None:
    self.mp_drawing = mp.solutions.drawing_utils
    self.mp_drawing_styles = mp.solutions.drawing_styles
    self.mp_hands = mp.solutions.hands
    self.detector = self.mp_hands.Hands(False, max_num_hands=1, min_detection_confidence=0.5)

  def detectHand(self, frame):
    hands = []
    frame = cv2.flip(frame, 1)
    annotated_image = frame.copy()
    results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    if results.multi_hand_landmarks is not None:
      for hand_landmarks in results.multi_hand_landmarks:
          hand = []
          self.mp_drawing.draw_landmarks(
              annotated_image,
              hand_landmarks,
              self.mp_hands.HAND_CONNECTIONS,
              self.mp_drawing_styles.get_default_hand_landmarks_style(),
              self.mp_drawing_styles.get_default_hand_connections_style())
          for landmark in hand_landmarks.landmark:
            hand.append(landmark.x)
            hand.append(landmark.y)
            hand.append(landmark.z)
          hands.append(hand)
    return hands, annotated_image

# %%
class CustomImageDataset(Dataset):
  def __init__(self, data_file):
      self.data = pd.read_csv(data_file)
      self.labels = torch.from_numpy(self.data.iloc[:, 0].to_numpy())

  def __len__(self):
      return len(self.data)

  def __getitem__(self, idx):
      one_hot_label = self.labels[idx]
      torch_data = torch.from_numpy(self.data.iloc[idx, 1:].to_numpy(dtype=np.float32))
      return torch_data, one_hot_label

# %%
class EarlyStopper:
  def __init__(self, patience=1, min_delta=0):
    self.patience = patience
    self.min_delta = min_delta
    self.counter = 0
    self.watched_metrics = np.inf

  def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, erly_stopper, optimizer):
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime('%d-%m %H:%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(label_dict_from_config_file("/content/hand_gesture.yaml")), task='MULTICLASS')
        for batch_number, data in enumerate(trainloader):
            inputs, labels = data
            optimizer.zero_grad()
            preds = model(inputs)
            loss = loss_function(preds, labels)
            loss.backward()
            optimizer.step()
            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(label_dict_from_config_file("/content/hand_gesture.yaml")), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)

        # Track best performance and save model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
            torch.save(model.state_dict(), best_model_path)
        if early_stopper.early_stop(avg_vloss):
            print(f"stopping at epoch {epoch}, minimum: {early_stopper.watched_metrics}")
            break

    model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH="./data/"
LIST_LABEL = label_dict_from_config_file("hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH,"landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH,"landmark_val.csv")
save_path = './models'
os.makedirs(save_path,exist_ok=True)

trainset = CustomImageDataset(train_path)
trainloader = torch.utils.data.DataLoader(trainset,batch_size=40,shuffle=True)

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset,batch_size=50, shuffle=False)

model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30,min_delta=0.01)
optimizer = optim.Adam(model.parameters(),lr=0.0001)

model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.25613346695899963, val:0.14675767719745636
# LOSS train 1.5998465281266432 valid 1.609969953695933
# Training vs. Validation Loss {'Training': 1.5998465281266432, 'Validation': 1.609969953695933} 1
# Training vs. Validation accuracy {'Training': 0.25613346695899963, 'Validation': 0.14675767719745636} 1
# Epoch 1:
# Accuracy train:0.3002943992614746, val:0.19112628698349
# LOSS train 1.580174106817979 valid 1.5895103812217712
# Training vs. Validation Loss {'Training': 1.580174106817979, 'Validation': 1.5895103812217712} 2
# Training vs. Validation accuracy {'Training': 0.3002943992614746, 'Validation': 0.19112628698349} 2
# Epoch 2:
# Accuracy train:0.36113837361335754, val:0.24573378264904022
# LOSS train 1.5630197525024414 valid 1.5659319559733074
# Training vs. Validation Loss {'Training': 1.5630197525024414, 'Validation': 1.5659319559733074} 3
# Training vs. Validation accuracy {'Training': 0.36113837361335754, 'Validation': 0.24573378264904022} 3
# Epoch 3:
# Accuracy train:0.3827281594276428, val:0.37542662024497986
# LOSS train 1.527819431745089 valid 1.538497010866801
# Training vs. Validation Loss {'Training': 1.527819431745089, 'Validation': 1.538497010866801} 4
# Training vs. Validation accuracy {'Training': 0.3827281594276428, 'Validation': 0.37542662024497986} 4
# Epoch 4:
# Accuracy train:0.44259077310562134, val:0.4163822531700134
# LOSS train 1.4857995739349952 valid 1.488808770974477
# Training vs. Validation Loss {'Training': 1.4857995739349952, 'Validation': 1.488808770974477} 5
# Training vs. Validation accuracy {'Training': 0.44259077310562134, 'Validation': 0.4163822531700134} 5
# Epoch 5:
# Accuracy train:0.5279685854911804, val:0.45392492413520813
# LOSS train 1.4074968512241657 valid 1.403150459130605
# Training vs. Validation Loss {'Training': 1.4074968512241657, 'Validation': 1.403150459130605} 6
# Training vs. Validation accuracy {'Training': 0.5279685854911804, 'Validation': 0.45392492413520813} 6
# Epoch 6:
# Accuracy train:0.5495584011077881, val:0.457337886095047
# LOSS train 1.2985555896392236 valid 1.2629668811957042
# Training vs. Validation Loss {'Training': 1.2985555896392236, 'Validation': 1.2629668811957042} 7
# Training vs. Validation accuracy {'Training': 0.5495584011077881, 'Validation': 0.457337886095047} 7
# Epoch 7:
# Accuracy train:0.5515211224555969, val:0.457337886095047
# LOSS train 1.1649010960872357 valid 1.1297615468502045
# Training vs. Validation Loss {'Training': 1.1649010960872357, 'Validation': 1.1297615468502045} 8
# Training vs. Validation accuracy {'Training': 0.5515211224555969, 'Validation': 0.457337886095047} 8
# Epoch 8:
# Accuracy train:0.5780176520347595, val:0.46416381001472473
# LOSS train 1.032856258062216 valid 0.9943641225496928
# Training vs. Validation Loss {'Training': 1.032856258062216, 'Validation': 0.9943641225496928} 9
# Training vs. Validation accuracy {'Training': 0.5780176520347595, 'Validation': 0.46416381001472473} 9
# Epoch 9:
# Accuracy train:0.6123650670051575, val:0.5563139915466309
# LOSS train 0.9378225757525518 valid 0.8926396866639456
# Training vs. Validation Loss {'Training': 0.9378225757525518, 'Validation': 0.8926396866639456} 10
# Training vs. Validation accuracy {'Training': 0.6123650670051575, 'Validation': 0.5563139915466309} 10
# Epoch 10:
# Accuracy train:0.6820412278175354, val:0.6109215021133423
# LOSS train 0.8130068412193885 valid 0.7563361885646979
# Training vs. Validation Loss {'Training': 0.8130068412193885, 'Validation': 0.7563361885646979} 11
# Training vs. Validation accuracy {'Training': 0.6820412278175354, 'Validation': 0.6109215021133423} 11
# Epoch 11:
# Accuracy train:0.7291462421417236, val:0.788395881652832
# LOSS train 0.7219432592391968 valid 0.6255006479720274
# Training vs. Validation Loss {'Training': 0.7219432592391968, 'Validation': 0.6255006479720274} 12
# Training vs. Validation accuracy {'Training': 0.7291462421417236, 'Validation': 0.788395881652832} 12
# Epoch 12:
# Accuracy train:0.8253189325332642, val:0.9010238647460938
# LOSS train 0.6298776291883909 valid 0.513266226897637
# Training vs. Validation Loss {'Training': 0.6298776291883909, 'Validation': 0.513266226897637} 13
# Training vs. Validation accuracy {'Training': 0.8253189325332642, 'Validation': 0.9010238647460938} 13
# Epoch 13:
# Accuracy train:0.8498528003692627, val:0.9863481521606445
# LOSS train 0.5617906302213669 valid 0.4042501163979371
# Training vs. Validation Loss {'Training': 0.5617906302213669, 'Validation': 0.4042501163979371} 14
# Training vs. Validation accuracy {'Training': 0.8498528003692627, 'Validation': 0.9863481521606445} 14
# Epoch 14:
# Accuracy train:0.8920510411262512, val:0.9863481521606445
# LOSS train 0.44928241119934964 valid 0.30945982163151103
# Training vs. Validation Loss {'Training': 0.44928241119934964, 'Validation': 0.30945982163151103} 15
# Training vs. Validation accuracy {'Training': 0.8920510411262512, 'Validation': 0.9863481521606445} 15
# Epoch 15:
# Accuracy train:0.9018645882606506, val:0.9863481521606445
# LOSS train 0.3915150177020293 valid 0.2191116502508521
# Training vs. Validation Loss {'Training': 0.3915150177020293, 'Validation': 0.2191116502508521} 16
# Training vs. Validation accuracy {'Training': 0.9018645882606506, 'Validation': 0.9863481521606445} 16
# Epoch 16:
# Accuracy train:0.9283611178398132, val:0.9897611141204834
# LOSS train 0.31968702433200985 valid 0.16566365429510674
# Training vs. Validation Loss {'Training': 0.31968702433200985, 'Validation': 0.16566365429510674} 17
# Training vs. Validation accuracy {'Training': 0.9283611178398132, 'Validation': 0.9897611141204834} 17
# Epoch 17:
# Accuracy train:0.9460254907608032, val:0.9863481521606445
# LOSS train 0.25808155364715135 valid 0.111794404219836
# Training vs. Validation Loss {'Training': 0.25808155364715135, 'Validation': 0.111794404219836} 18
# Training vs. Validation accuracy {'Training': 0.9460254907608032, 'Validation': 0.9863481521606445} 18
# Epoch 18:
# Accuracy train:0.9450441598892212, val:0.9829351305961609
# LOSS train 0.2086198848600571 valid 0.07988170922423403
# Training vs. Validation Loss {'Training': 0.2086198848600571, 'Validation': 0.07988170922423403} 19
# Training vs. Validation accuracy {'Training': 0.9450441598892212, 'Validation': 0.9829351305961609} 19
# Epoch 19:
# Accuracy train:0.965652585029602, val:0.9829351305961609
# LOSS train 0.18112256120030695 valid 0.06084900725788126
# Training vs. Validation Loss {'Training': 0.18112256120030695, 'Validation': 0.06084900725788126} 20
# Training vs. Validation accuracy {'Training': 0.965652585029602, 'Validation': 0.9829351305961609} 20
# Epoch 20:
# Accuracy train:0.965652585029602, val:0.9829351305961609
# LOSS train 0.14570937420313174 valid 0.05608500260859728
# Training vs. Validation Loss {'Training': 0.14570937420313174, 'Validation': 0.05608500260859728} 21
# Training vs. Validation accuracy {'Training': 0.965652585029602, 'Validation': 0.9829351305961609} 21
# Epoch 21:
# Accuracy train:0.9735034108161926, val:0.9829351305961609
# LOSS train 0.16376421614908254 valid 0.05264791345689446
# Training vs. Validation Loss {'Training': 0.16376421614908254, 'Validation': 0.05264791345689446} 22
# Training vs. Validation accuracy {'Training': 0.9735034108161926, 'Validation': 0.9829351305961609} 22
# Epoch 22:
# Accuracy train:0.9744848012924194, val:0.9829351305961609
# LOSS train 0.12032896316108796 valid 0.044882329452472426
# Training vs. Validation Loss {'Training': 0.12032896316108796, 'Validation': 0.044882329452472426} 23
# Training vs. Validation accuracy {'Training': 0.9744848012924194, 'Validation': 0.9829351305961609} 23
# Epoch 23:
# Accuracy train:0.9793915748596191, val:0.9829351305961609
# LOSS train 0.1132187253007522 valid 0.03507075264739493
# Training vs. Validation Loss {'Training': 0.1132187253007522, 'Validation': 0.03507075264739493} 24
# Training vs. Validation accuracy {'Training': 0.9793915748596191, 'Validation': 0.9829351305961609} 24
# Epoch 24:
# Accuracy train:0.9754661321640015, val:0.9829351305961609
# LOSS train 0.102578737701361 valid 0.03733556196675636
# Training vs. Validation Loss {'Training': 0.102578737701361, 'Validation': 0.03733556196675636} 25
# Training vs. Validation accuracy {'Training': 0.9754661321640015, 'Validation': 0.9829351305961609} 25
# Epoch 25:
# Accuracy train:0.9754661321640015, val:0.9931740760803223
# LOSS train 0.11478335653933194 valid 0.02823235436032216
# Training vs. Validation Loss {'Training': 0.11478335653933194, 'Validation': 0.02823235436032216} 26
# Training vs. Validation accuracy {'Training': 0.9754661321640015, 'Validation': 0.9931740760803223} 26
# Epoch 26:
# Accuracy train:0.9803729057312012, val:0.9829351305961609
# LOSS train 0.08833667463981189 valid 0.032550068106502295
# Training vs. Validation Loss {'Training': 0.08833667463981189, 'Validation': 0.032550068106502295} 27
# Training vs. Validation accuracy {'Training': 0.9803729057312012, 'Validation': 0.9829351305961609} 27
# Epoch 27:
# Accuracy train:0.981354296207428, val:0.9931740760803223
# LOSS train 0.09651017396782453 valid 0.024146911207935773
# Training vs. Validation Loss {'Training': 0.09651017396782453, 'Validation': 0.024146911207935773} 28
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9931740760803223} 28
# Epoch 28:
# Accuracy train:0.98233562707901, val:0.9829351305961609
# LOSS train 0.073429292282806 valid 0.036827800708124414
# Training vs. Validation Loss {'Training': 0.073429292282806, 'Validation': 0.036827800708124414} 29
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9829351305961609} 29
# Epoch 29:
# Accuracy train:0.981354296207428, val:0.9897611141204834
# LOSS train 0.07754250049877626 valid 0.032269671826118916
# Training vs. Validation Loss {'Training': 0.07754250049877626, 'Validation': 0.032269671826118916} 30
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9897611141204834} 30
# Epoch 30:
# Accuracy train:0.981354296207428, val:0.9863481521606445
# LOSS train 0.06471956951113847 valid 0.029317948162012424
# Training vs. Validation Loss {'Training': 0.06471956951113847, 'Validation': 0.029317948162012424} 31
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9863481521606445} 31
# Epoch 31:
# Accuracy train:0.983316957950592, val:0.9829351305961609
# LOSS train 0.08212157138265096 valid 0.03373311286850367
# Training vs. Validation Loss {'Training': 0.08212157138265096, 'Validation': 0.03373311286850367} 32
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9829351305961609} 32
# Epoch 32:
# Accuracy train:0.98233562707901, val:0.9897611141204834
# LOSS train 0.0731105888620592 valid 0.034715783100788634
# Training vs. Validation Loss {'Training': 0.0731105888620592, 'Validation': 0.034715783100788634} 33
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9897611141204834} 33
# Epoch 33:
# Accuracy train:0.9754661321640015, val:0.9931740760803223
# LOSS train 0.06877967331988308 valid 0.018050456087318405
# Training vs. Validation Loss {'Training': 0.06877967331988308, 'Validation': 0.018050456087318405} 34
# Training vs. Validation accuracy {'Training': 0.9754661321640015, 'Validation': 0.9931740760803223} 34
# Epoch 34:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.06127798972794643 valid 0.0248577910970198
# Training vs. Validation Loss {'Training': 0.06127798972794643, 'Validation': 0.0248577910970198} 35
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 35
# Epoch 35:
# Accuracy train:0.9872424006462097, val:0.9897611141204834
# LOSS train 0.06722225410004075 valid 0.030337811367644463
# Training vs. Validation Loss {'Training': 0.06722225410004075, 'Validation': 0.030337811367644463} 36
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9897611141204834} 36
# Epoch 36:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.05617271249110882 valid 0.022337556788746344
# Training vs. Validation Loss {'Training': 0.05617271249110882, 'Validation': 0.022337556788746344} 37
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 37
# Epoch 37:
# Accuracy train:0.9882237315177917, val:0.9897611141204834
# LOSS train 0.0640444950057337 valid 0.026870973809612526
# Training vs. Validation Loss {'Training': 0.0640444950057337, 'Validation': 0.026870973809612526} 38
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9897611141204834} 38
# Epoch 38:
# Accuracy train:0.983316957950592, val:0.9965870380401611
# LOSS train 0.05977539345622063 valid 0.015502872466944003
# Training vs. Validation Loss {'Training': 0.05977539345622063, 'Validation': 0.015502872466944003} 39
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9965870380401611} 39
# Epoch 39:
# Accuracy train:0.9852796792984009, val:0.9897611141204834
# LOSS train 0.050373402603257164 valid 0.028690788048455335
# Training vs. Validation Loss {'Training': 0.050373402603257164, 'Validation': 0.028690788048455335} 40
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9897611141204834} 40
# Epoch 40:
# Accuracy train:0.9892051219940186, val:0.9897611141204834
# LOSS train 0.05045401677489281 valid 0.02132148193049943
# Training vs. Validation Loss {'Training': 0.05045401677489281, 'Validation': 0.02132148193049943} 41
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9897611141204834} 41
# Epoch 41:
# Accuracy train:0.981354296207428, val:0.9965870380401611
# LOSS train 0.0666510396135541 valid 0.008728533073735889
# Training vs. Validation Loss {'Training': 0.0666510396135541, 'Validation': 0.008728533073735889} 42
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9965870380401611} 42
# Epoch 42:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.057557406942718305 valid 0.023798265306443984
# Training vs. Validation Loss {'Training': 0.057557406942718305, 'Validation': 0.023798265306443984} 43
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 43
# Epoch 43:
# Accuracy train:0.9872424006462097, val:0.9965870380401611
# LOSS train 0.05932143749669194 valid 0.011297204163080702
# Training vs. Validation Loss {'Training': 0.05932143749669194, 'Validation': 0.011297204163080702} 44
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9965870380401611} 44
# Epoch 44:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.05521863747316484 valid 0.022586158362779923
# Training vs. Validation Loss {'Training': 0.05521863747316484, 'Validation': 0.022586158362779923} 45
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 45
# Epoch 45:
# Accuracy train:0.98233562707901, val:0.9863481521606445
# LOSS train 0.0694140767893539 valid 0.040292022248953195
# Training vs. Validation Loss {'Training': 0.0694140767893539, 'Validation': 0.040292022248953195} 46
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9863481521606445} 46
# Epoch 46:
# Accuracy train:0.9901864528656006, val:0.9863481521606445
# LOSS train 0.048682051997345224 valid 0.028535755266299628
# Training vs. Validation Loss {'Training': 0.048682051997345224, 'Validation': 0.028535755266299628} 47
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9863481521606445} 47
# Epoch 47:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.05312109971418977 valid 0.02836057966851513
# Training vs. Validation Loss {'Training': 0.05312109971418977, 'Validation': 0.02836057966851513} 48
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 48
# Epoch 48:
# Accuracy train:0.9872424006462097, val:0.9897611141204834
# LOSS train 0.05274153787356157 valid 0.026361300132217973
# Training vs. Validation Loss {'Training': 0.05274153787356157, 'Validation': 0.026361300132217973} 49
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9897611141204834} 49
# Epoch 49:
# Accuracy train:0.9882237315177917, val:0.9965870380401611
# LOSS train 0.0443163737654686 valid 0.013832817947331932
# Training vs. Validation Loss {'Training': 0.0443163737654686, 'Validation': 0.013832817947331932} 50
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9965870380401611} 50
# Epoch 50:
# Accuracy train:0.9892051219940186, val:0.9897611141204834
# LOSS train 0.06901780266959506 valid 0.023022649725893036
# Training vs. Validation Loss {'Training': 0.06901780266959506, 'Validation': 0.023022649725893036} 51
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9897611141204834} 51
# Epoch 51:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.048273698426783085 valid 0.019424960930336965
# Training vs. Validation Loss {'Training': 0.048273698426783085, 'Validation': 0.019424960930336965} 52
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 52
# Epoch 52:
# Accuracy train:0.9892051219940186, val:0.9965870380401611
# LOSS train 0.049783315581197925 valid 0.008565233048405693
# Training vs. Validation Loss {'Training': 0.049783315581197925, 'Validation': 0.008565233048405693} 53
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9965870380401611} 53
# Epoch 53:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.040457736127651654 valid 0.020466015228521428
# Training vs. Validation Loss {'Training': 0.040457736127651654, 'Validation': 0.020466015228521428} 54
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 54
# Epoch 54:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.04131218156992243 valid 0.02213602432978708
# Training vs. Validation Loss {'Training': 0.04131218156992243, 'Validation': 0.02213602432978708} 55
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 55
# Epoch 55:
# Accuracy train:0.9882237315177917, val:0.979522168636322
# LOSS train 0.043455415996364676 valid 0.04748827548974077
# Training vs. Validation Loss {'Training': 0.043455415996364676, 'Validation': 0.04748827548974077} 56
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.979522168636322} 56
# Epoch 56:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.04025231830130976 valid 0.022598636570061597
# Training vs. Validation Loss {'Training': 0.04025231830130976, 'Validation': 0.022598636570061597} 57
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 57
# Epoch 57:
# Accuracy train:0.9931305050849915, val:0.9863481521606445
# LOSS train 0.031971479595925376 valid 0.029835857943908195
# Training vs. Validation Loss {'Training': 0.031971479595925376, 'Validation': 0.029835857943908195} 58
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9863481521606445} 58
# Epoch 58:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.04666368829874465 valid 0.025039443313895998
# Training vs. Validation Loss {'Training': 0.04666368829874465, 'Validation': 0.025039443313895998} 59
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 59
# Epoch 59:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.05514791711735038 valid 0.016813142882104632
# Training vs. Validation Loss {'Training': 0.05514791711735038, 'Validation': 0.016813142882104632} 60
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 60
# Epoch 60:
# Accuracy train:0.9882237315177917, val:0.9965870380401611
# LOSS train 0.051213926098381095 valid 0.01611666784568418
# Training vs. Validation Loss {'Training': 0.051213926098381095, 'Validation': 0.01611666784568418} 61
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9965870380401611} 61
# Epoch 61:
# Accuracy train:0.9931305050849915, val:0.9829351305961609
# LOSS train 0.03594350647360373 valid 0.04405769792629144
# Training vs. Validation Loss {'Training': 0.03594350647360373, 'Validation': 0.04405769792629144} 62
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9829351305961609} 62
# Epoch 62:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.04504890189631484 valid 0.014531013629493827
# Training vs. Validation Loss {'Training': 0.04504890189631484, 'Validation': 0.014531013629493827} 63
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 63
# Epoch 63:
# Accuracy train:0.9911677837371826, val:0.9863481521606445
# LOSS train 0.049140398677151934 valid 0.031128741274490796
# Training vs. Validation Loss {'Training': 0.049140398677151934, 'Validation': 0.031128741274490796} 64
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9863481521606445} 64
# Epoch 64:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.03327781053331609 valid 0.02565109351295784
# Training vs. Validation Loss {'Training': 0.03327781053331609, 'Validation': 0.02565109351295784} 65
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 65
# Epoch 65:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.048660347381463416 valid 0.022953536332200503
# Training vs. Validation Loss {'Training': 0.048660347381463416, 'Validation': 0.022953536332200503} 66
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 66
# Epoch 66:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.02813035898949378 valid 0.021892143176046375
# Training vs. Validation Loss {'Training': 0.02813035898949378, 'Validation': 0.021892143176046375} 67
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 67
# Epoch 67:
# Accuracy train:0.9872424006462097, val:0.9897611141204834
# LOSS train 0.04006101187461844 valid 0.023826666740509
# Training vs. Validation Loss {'Training': 0.04006101187461844, 'Validation': 0.023826666740509} 68
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9897611141204834} 68
# Epoch 68:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.025255507950742658 valid 0.02354265234172696
# Training vs. Validation Loss {'Training': 0.025255507950742658, 'Validation': 0.02354265234172696} 69
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 69
# Epoch 69:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.03300388013191808 valid 0.017286146181807755
# Training vs. Validation Loss {'Training': 0.03300388013191808, 'Validation': 0.017286146181807755} 70
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 70
# Epoch 70:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.03497711896824722 valid 0.008507999134508282
# Training vs. Validation Loss {'Training': 0.03497711896824722, 'Validation': 0.008507999134508282} 71
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 71
# Epoch 71:
# Accuracy train:0.9872424006462097, val:0.9863481521606445
# LOSS train 0.0444625821412326 valid 0.02338612976798989
# Training vs. Validation Loss {'Training': 0.0444625821412326, 'Validation': 0.02338612976798989} 72
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9863481521606445} 72
# Epoch 72:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.0354074699123605 valid 0.013231371595414506
# Training vs. Validation Loss {'Training': 0.0354074699123605, 'Validation': 0.013231371595414506} 73
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 73
# Epoch 73:
# Accuracy train:0.9892051219940186, val:0.9897611141204834
# LOSS train 0.030054540794271115 valid 0.020834767705916118
# Training vs. Validation Loss {'Training': 0.030054540794271115, 'Validation': 0.020834767705916118} 74
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9897611141204834} 74
# Epoch 74:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.03158688489705897 valid 0.014746832271915386
# Training vs. Validation Loss {'Training': 0.03158688489705897, 'Validation': 0.014746832271915386} 75
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 75
# Epoch 75:
# Accuracy train:0.9911677837371826, val:0.9863481521606445
# LOSS train 0.03574608571719951 valid 0.034916921328507065
# Training vs. Validation Loss {'Training': 0.03574608571719951, 'Validation': 0.034916921328507065} 76
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9863481521606445} 76
# Epoch 76:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.03619961651901786 valid 0.01597445800704615
# Training vs. Validation Loss {'Training': 0.03619961651901786, 'Validation': 0.01597445800704615} 77
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 77
# Epoch 77:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.03418817774106104 valid 0.015140715010147687
# Training vs. Validation Loss {'Training': 0.03418817774106104, 'Validation': 0.015140715010147687} 78
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 78
# Epoch 78:
# Accuracy train:0.9892051219940186, val:0.9965870380401611
# LOSS train 0.025612880296718616 valid 0.012796290605820104
# Training vs. Validation Loss {'Training': 0.025612880296718616, 'Validation': 0.012796290605820104} 79
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9965870380401611} 79
# Epoch 79:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.04389422725384625 valid 0.01859924969160905
# Training vs. Validation Loss {'Training': 0.04389422725384625, 'Validation': 0.01859924969160905} 80
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 80
# Epoch 80:
# Accuracy train:0.9921491742134094, val:0.9863481521606445
# LOSS train 0.02914021842969725 valid 0.026309377318890863
# Training vs. Validation Loss {'Training': 0.02914021842969725, 'Validation': 0.026309377318890863} 81
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9863481521606445} 81
# Epoch 81:
# Accuracy train:0.9911677837371826, val:0.9829351305961609
# LOSS train 0.03739661133239189 valid 0.03409697283973401
# Training vs. Validation Loss {'Training': 0.03739661133239189, 'Validation': 0.03409697283973401} 82
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9829351305961609} 82
# Epoch 82:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.031907639412495956 valid 0.013999666463405447
# Training vs. Validation Loss {'Training': 0.031907639412495956, 'Validation': 0.013999666463405447} 83
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 83
# Epoch 83:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.027733503419977542 valid 0.018100627823590305
# Training vs. Validation Loss {'Training': 0.027733503419977542, 'Validation': 0.018100627823590305} 84
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 84
# Epoch 84:
# Accuracy train:0.9892051219940186, val:1.0
# LOSS train 0.03300544583740143 valid 0.010646285223553301
# Training vs. Validation Loss {'Training': 0.03300544583740143, 'Validation': 0.010646285223553301} 85
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 1.0} 85
# Epoch 85:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.03167316881724848 valid 0.016862773863977054
# Training vs. Validation Loss {'Training': 0.03167316881724848, 'Validation': 0.016862773863977054} 86
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 86
# Epoch 86:
# Accuracy train:0.9921491742134094, val:0.9897611141204834
# LOSS train 0.029318934172176972 valid 0.01988921254140526
# Training vs. Validation Loss {'Training': 0.029318934172176972, 'Validation': 0.01988921254140526} 87
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9897611141204834} 87
# Epoch 87:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.02740108834293026 valid 0.020595924905289092
# Training vs. Validation Loss {'Training': 0.02740108834293026, 'Validation': 0.020595924905289092} 88
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 88
# Epoch 88:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.03843636536755814 valid 0.023883799243246056
# Training vs. Validation Loss {'Training': 0.03843636536755814, 'Validation': 0.023883799243246056} 89
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 89
# Epoch 89:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.039658941149425045 valid 0.026685129854323957
# Training vs. Validation Loss {'Training': 0.039658941149425045, 'Validation': 0.026685129854323957} 90
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 90
# Epoch 90:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.031233660240944188 valid 0.017950745329244455
# Training vs. Validation Loss {'Training': 0.031233660240944188, 'Validation': 0.017950745329244455} 91
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 91
# Epoch 91:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.03549760125147609 valid 0.014432230711236116
# Training vs. Validation Loss {'Training': 0.03549760125147609, 'Validation': 0.014432230711236116} 92
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 92
# Epoch 92:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.02629368032257144 valid 0.017440424108144725
# Training vs. Validation Loss {'Training': 0.02629368032257144, 'Validation': 0.017440424108144725} 93
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 93
# Epoch 93:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.03473834364782446 valid 0.013667396264963827
# Training vs. Validation Loss {'Training': 0.03473834364782446, 'Validation': 0.013667396264963827} 94
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 94
# Epoch 94:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.03392069270082105 valid 0.012415015950902367
# Training vs. Validation Loss {'Training': 0.03392069270082105, 'Validation': 0.012415015950902367} 95
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 95
# Epoch 95:
# Accuracy train:0.9931305050849915, val:0.9863481521606445
# LOSS train 0.0301816803134548 valid 0.02628336703039243
# Training vs. Validation Loss {'Training': 0.0301816803134548, 'Validation': 0.02628336703039243} 96
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9863481521606445} 96
# Epoch 96:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.032187963620974466 valid 0.01849694097457662
# Training vs. Validation Loss {'Training': 0.032187963620974466, 'Validation': 0.01849694097457662} 97
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 97
# Epoch 97:
# Accuracy train:0.9892051219940186, val:0.9897611141204834
# LOSS train 0.026875421404838562 valid 0.02809078673734196
# Training vs. Validation Loss {'Training': 0.026875421404838562, 'Validation': 0.02809078673734196} 98
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9897611141204834} 98
# Epoch 98:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.03007570370279539 valid 0.014115920527122702
# Training vs. Validation Loss {'Training': 0.03007570370279539, 'Validation': 0.014115920527122702} 99
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 99
# Epoch 99:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.03061405441705854 valid 0.017080940125841455
# Training vs. Validation Loss {'Training': 0.03061405441705854, 'Validation': 0.017080940125841455} 100
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 100
# Epoch 100:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.02922693646262185 valid 0.01789710976826579
# Training vs. Validation Loss {'Training': 0.02922693646262185, 'Validation': 0.01789710976826579} 101
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 101
# Epoch 101:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.0241928200971765 valid 0.018869496372417416
# Training vs. Validation Loss {'Training': 0.0241928200971765, 'Validation': 0.018869496372417416} 102
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 102
# Epoch 102:
# Accuracy train:0.9950932264328003, val:0.9863481521606445
# LOSS train 0.02839252095257577 valid 0.02606149166194882
# Training vs. Validation Loss {'Training': 0.02839252095257577, 'Validation': 0.02606149166194882} 103
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9863481521606445} 103
# Epoch 103:
# Accuracy train:0.9892051219940186, val:0.9965870380401611
# LOSS train 0.02407157806178125 valid 0.01076862862392621
# Training vs. Validation Loss {'Training': 0.02407157806178125, 'Validation': 0.01076862862392621} 104
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9965870380401611} 104
# Epoch 104:
# Accuracy train:0.9901864528656006, val:0.9897611141204834
# LOSS train 0.024742904835595533 valid 0.02515126106969016
# Training vs. Validation Loss {'Training': 0.024742904835595533, 'Validation': 0.02515126106969016} 105
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9897611141204834} 105
# Epoch 105:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.02724319875974638 valid 0.01703771063845731
# Training vs. Validation Loss {'Training': 0.02724319875974638, 'Validation': 0.01703771063845731} 106
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 106
# Epoch 106:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.01957145744549612 valid 0.017601948483293956
# Training vs. Validation Loss {'Training': 0.01957145744549612, 'Validation': 0.017601948483293956} 107
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 107
# Epoch 107:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.02274532373009536 valid 0.010090143030007917
# Training vs. Validation Loss {'Training': 0.02274532373009536, 'Validation': 0.010090143030007917} 108
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 108
# Epoch 108:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.024532674017022006 valid 0.021887016093425398
# Training vs. Validation Loss {'Training': 0.024532674017022006, 'Validation': 0.021887016093425398} 109
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 109
# Epoch 109:
# Accuracy train:0.9911677837371826, val:1.0
# LOSS train 0.03627459776516144 valid 0.007364716292888336
# Training vs. Validation Loss {'Training': 0.03627459776516144, 'Validation': 0.007364716292888336} 110
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 1.0} 110
# Epoch 110:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.019656435743225023 valid 0.018065114909442553
# Training vs. Validation Loss {'Training': 0.019656435743225023, 'Validation': 0.018065114909442553} 111
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 111
# Epoch 111:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.01671380836677809 valid 0.008099301058261213
# Training vs. Validation Loss {'Training': 0.01671380836677809, 'Validation': 0.008099301058261213} 112
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 112
# Epoch 112:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.023131312157672185 valid 0.01809010462506914
# Training vs. Validation Loss {'Training': 0.023131312157672185, 'Validation': 0.01809010462506914} 113
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 113
# Epoch 113:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.033175931576317035 valid 0.015726480890426348
# Training vs. Validation Loss {'Training': 0.033175931576317035, 'Validation': 0.015726480890426348} 114
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 114
# Epoch 114:
# Accuracy train:0.9960745573043823, val:0.9965870380401611
# LOSS train 0.020864674248374425 valid 0.012236206563443375
# Training vs. Validation Loss {'Training': 0.020864674248374425, 'Validation': 0.012236206563443375} 115
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9965870380401611} 115
# Epoch 115:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.014800297239652047 valid 0.01871835199576329
# Training vs. Validation Loss {'Training': 0.014800297239652047, 'Validation': 0.01871835199576329} 116
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 116
# Epoch 116:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.014692319789901376 valid 0.017831049728973387
# Training vs. Validation Loss {'Training': 0.014692319789901376, 'Validation': 0.017831049728973387} 117
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 117
# Epoch 117:
# Accuracy train:0.9960745573043823, val:0.9863481521606445
# LOSS train 0.01978927239542827 valid 0.03676901661037372
# Training vs. Validation Loss {'Training': 0.01978927239542827, 'Validation': 0.03676901661037372} 118
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9863481521606445} 118
# Epoch 118:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.014875813785832949 valid 0.023470223801742424
# Training vs. Validation Loss {'Training': 0.014875813785832949, 'Validation': 0.023470223801742424} 119
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 119
# Epoch 119:
# Accuracy train:0.9901864528656006, val:0.9863481521606445
# LOSS train 0.035449751413230285 valid 0.026827929283551082
# Training vs. Validation Loss {'Training': 0.035449751413230285, 'Validation': 0.026827929283551082} 120
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9863481521606445} 120
# Epoch 120:
# Accuracy train:0.9980372786521912, val:0.9897611141204834
# LOSS train 0.021171545479983952 valid 0.035835059478548224
# Training vs. Validation Loss {'Training': 0.021171545479983952, 'Validation': 0.035835059478548224} 121
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9897611141204834} 121
# Epoch 121:
# Accuracy train:0.9931305050849915, val:0.9863481521606445
# LOSS train 0.02680408283441256 valid 0.03356647395624653
# Training vs. Validation Loss {'Training': 0.02680408283441256, 'Validation': 0.03356647395624653} 122
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9863481521606445} 122
# Epoch 122:
# Accuracy train:0.9911677837371826, val:0.9863481521606445
# LOSS train 0.029315203851393353 valid 0.0369372122457842
# Training vs. Validation Loss {'Training': 0.029315203851393353, 'Validation': 0.0369372122457842} 123
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9863481521606445} 123
# Epoch 123:
# Accuracy train:0.9950932264328003, val:0.9863481521606445
# LOSS train 0.01875601408895678 valid 0.033384967699344514
# Training vs. Validation Loss {'Training': 0.01875601408895678, 'Validation': 0.033384967699344514} 124
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9863481521606445} 124
# Epoch 124:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.015966225303530406 valid 0.014012001097934027
# Training vs. Validation Loss {'Training': 0.015966225303530406, 'Validation': 0.014012001097934027} 125
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 125
# Epoch 125:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.018031408327470463 valid 0.011900289472521308
# Training vs. Validation Loss {'Training': 0.018031408327470463, 'Validation': 0.011900289472521308} 126
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 126
# Epoch 126:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.022576199280313 valid 0.01595558486818997
# Training vs. Validation Loss {'Training': 0.022576199280313, 'Validation': 0.01595558486818997} 127
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 127
# Epoch 127:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.013944919771837214 valid 0.01762464881559822
# Training vs. Validation Loss {'Training': 0.013944919771837214, 'Validation': 0.01762464881559822} 128
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 128
# Epoch 128:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.015821552817494824 valid 0.02215472354582933
# Training vs. Validation Loss {'Training': 0.015821552817494824, 'Validation': 0.02215472354582933} 129
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 129
# Epoch 129:
# Accuracy train:0.9970559477806091, val:0.9863481521606445
# LOSS train 0.014948778785765171 valid 0.023133081387660088
# Training vs. Validation Loss {'Training': 0.014948778785765171, 'Validation': 0.023133081387660088} 130
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9863481521606445} 130
# Epoch 130:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.01997318177913817 valid 0.011623767119317563
# Training vs. Validation Loss {'Training': 0.01997318177913817, 'Validation': 0.011623767119317563} 131
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 131
# Epoch 131:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.021015320483666774 valid 0.02102549424262179
# Training vs. Validation Loss {'Training': 0.021015320483666774, 'Validation': 0.02102549424262179} 132
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 132
# Epoch 132:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.016705239950589694 valid 0.01879161185773152
# Training vs. Validation Loss {'Training': 0.016705239950589694, 'Validation': 0.01879161185773152} 133
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 133
# Epoch 133:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.02084489507923046 valid 0.015647303371935095
# Training vs. Validation Loss {'Training': 0.02084489507923046, 'Validation': 0.015647303371935095} 134
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 134
# Epoch 134:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.019598234279188685 valid 0.0182276213913705
# Training vs. Validation Loss {'Training': 0.019598234279188685, 'Validation': 0.0182276213913705} 135
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 135
# Epoch 135:
# Accuracy train:0.9960745573043823, val:0.9863481521606445
# LOSS train 0.017969585520824276 valid 0.020543599944318203
# Training vs. Validation Loss {'Training': 0.017969585520824276, 'Validation': 0.020543599944318203} 136
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9863481521606445} 136
# Epoch 136:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.012678984390312018 valid 0.01225801540326188
# Training vs. Validation Loss {'Training': 0.012678984390312018, 'Validation': 0.01225801540326188} 137
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 137
# Epoch 137:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.023900381363861155 valid 0.012482159498963105
# Training vs. Validation Loss {'Training': 0.023900381363861155, 'Validation': 0.012482159498963105} 138
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 138
# Epoch 138:
# Accuracy train:0.9941118955612183, val:0.9863481521606445
# LOSS train 0.027879856473121505 valid 0.020250355923752277
# Training vs. Validation Loss {'Training': 0.027879856473121505, 'Validation': 0.020250355923752277} 139
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9863481521606445} 139
# Epoch 139:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.019376249625705756 valid 0.017245973729340374
# Training vs. Validation Loss {'Training': 0.019376249625705756, 'Validation': 0.017245973729340374} 140
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 140
# Epoch 140:
# Accuracy train:0.9980372786521912, val:0.9965870380401611
# LOSS train 0.010643063422041731 valid 0.015075980430684885
# Training vs. Validation Loss {'Training': 0.010643063422041731, 'Validation': 0.015075980430684885} 141
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9965870380401611} 141
# Epoch 141:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.022757837992125694 valid 0.016785385900741783
# Training vs. Validation Loss {'Training': 0.022757837992125694, 'Validation': 0.016785385900741783} 142
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 142
# Epoch 142:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.01852164745986766 valid 0.017491559189238615
# Training vs. Validation Loss {'Training': 0.01852164745986766, 'Validation': 0.017491559189238615} 143
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 143
# Epoch 143:
# Accuracy train:0.9980372786521912, val:0.9897611141204834
# LOSS train 0.014321739606272716 valid 0.024775001965094152
# Training vs. Validation Loss {'Training': 0.014321739606272716, 'Validation': 0.024775001965094152} 144
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9897611141204834} 144
# Epoch 144:
# Accuracy train:0.9941118955612183, val:0.9829351305961609
# LOSS train 0.02494505554652558 valid 0.04192063751456724
# Training vs. Validation Loss {'Training': 0.02494505554652558, 'Validation': 0.04192063751456724} 145
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9829351305961609} 145
# Epoch 145:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.012012857045472348 valid 0.01568294911103389
# Training vs. Validation Loss {'Training': 0.012012857045472348, 'Validation': 0.01568294911103389} 146
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 146
# Epoch 146:
# Accuracy train:0.9960745573043823, val:0.9829351305961609
# LOSS train 0.013083654940531302 valid 0.05054565333726657
# Training vs. Validation Loss {'Training': 0.013083654940531302, 'Validation': 0.05054565333726657} 147
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9829351305961609} 147
# Epoch 147:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.023536888170593347 valid 0.04732208333329879
# Training vs. Validation Loss {'Training': 0.023536888170593347, 'Validation': 0.04732208333329879} 148
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 148
# Epoch 148:
# Accuracy train:0.9970559477806091, val:0.9863481521606445
# LOSS train 0.011279371390768435 valid 0.03371205021726572
# Training vs. Validation Loss {'Training': 0.011279371390768435, 'Validation': 0.03371205021726572} 149
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9863481521606445} 149
# Epoch 149:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.020075882207423162 valid 0.02329523040058253
# Training vs. Validation Loss {'Training': 0.020075882207423162, 'Validation': 0.02329523040058253} 150
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 150
# Epoch 150:
# Accuracy train:0.9941118955612183, val:0.9863481521606445
# LOSS train 0.024641412612534344 valid 0.03801130457442525
# Training vs. Validation Loss {'Training': 0.024641412612534344, 'Validation': 0.03801130457442525} 151
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9863481521606445} 151
# Epoch 151:
# Accuracy train:0.9960745573043823, val:0.9829351305961609
# LOSS train 0.015996221750706006 valid 0.05430965422280565
# Training vs. Validation Loss {'Training': 0.015996221750706006, 'Validation': 0.05430965422280565} 152
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9829351305961609} 152
# Epoch 152:
# Accuracy train:0.9950932264328003, val:0.9829351305961609
# LOSS train 0.020199477607652973 valid 0.04944574446627333
# Training vs. Validation Loss {'Training': 0.020199477607652973, 'Validation': 0.04944574446627333} 153
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9829351305961609} 153
# Epoch 153:
# Accuracy train:0.9960745573043823, val:0.9829351305961609
# LOSS train 0.014371827052225573 valid 0.034114945685767374
# Training vs. Validation Loss {'Training': 0.014371827052225573, 'Validation': 0.034114945685767374} 154
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9829351305961609} 154
# stopping at epoch 153, minimum: 0.007364716292888336
# tensor(0.9829)
